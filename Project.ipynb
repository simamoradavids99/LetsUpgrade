# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the dataset
df = pd.read_csv('/content/pubg - Dr. Darshan Ingle.csv')

# %%
#2. check the data type of the columns
df.dtypes
# Out:
# Id                  object
# groupId             object
# matchId             object
# assists              int64
# boosts               int64
# damageDealt        float64
# DBNOs                int64
# headshotKills        int64
# heals                int64
# killPlace            int64
# killPoints           int64
# kills                int64
# killStreaks          int64
# longestKill        float64
# matchDuration        int64
# matchType           object
# maxPlace             int64
# numGroups            int64
# rankPoints           int64
# revives              int64
# rideDistance       float64
# roadKills            int64
# swimDistance       float64
# teamKills            int64
# vehicleDestroys      int64
# walkDistance       float64
# weaponsAcquired      int64
# winPoints            int64
# winPlacePerc       float64
# dtype: object

# %%
#3. find the summary of the numerical columns
df.describe()
# Out:
#             assists        boosts  ...   winPoints  winPlacePerc
# count  10000.000000  10000.000000  ...  10000.0000  10000.000000
# mean       0.234600      1.088500  ...    609.3440      0.469926
# std        0.575149      1.703279  ...    739.7924      0.304508
# min        0.000000      0.000000  ...      0.0000      0.000000
# 25%        0.000000      0.000000  ...      0.0000      0.200000
# 50%        0.000000      0.000000  ...      0.0000      0.458300
# 75%        0.000000      2.000000  ...   1495.0000      0.735100
# max        7.000000     18.000000  ...   1863.0000      1.000000
#
# [8 rows x 25 columns]

# %%
# 4. the average pepole kills how many players
df['kills'].mean()
# Out:
# 0.9134

# %%
# 5. 99% of people have how many kills?
a = int(np.percentile(df.kills, 99))
print( "%d kills" % (a) )
# Out:
# 7 kills

# %%
#6. The most kills ever recorded are how much?
df['kills'].max()
# Out:
# 35

# %%
#7. print all the columns of the dataframe.
print(df.columns)
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
#8. Comment on distribution of the match's duration. Use seaborn.
sns.displot(df['matchDuration'])

# %%
#9 Comment on distribution of the walk distance. Use seaborn.
sns.displot(df['walkDistance'])

# %%
#10. Plot distribution of the match's duration vs walk distance one below the other
plt.style.use('fast')
plt.figure()
plt.subplot(2,1,1)
plt.plot(df['matchDuration'],'--')
plt.subplot(2,1,2)
plt.plot(df['walkDistance'],'-')

# %%
#11. Plot distribution of the match's duration vs walk distance side by side.
plt.style.use('seaborn-darkgrid')
plt.figure()
plt.subplot(1,2,1)
plt.plot(df['matchDuration'],'--')
plt.subplot(1,2,2)
plt.plot(df['walkDistance'],'--')

# %%
#12. Pairplot the dataframe. Comment on kills vs damage dealt, Comment on maxPlace vs numGroups.
sns.pairplot(df.sample(100), height = 2.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#13. How many unique values are there in 'matchType' and what are their counts?
print(pd.unique(df['matchType']))

print(len(pd.unique(df['matchType'])))
# Out:
# ['squad-fpp' 'squad' 'duo-fpp' 'solo-fpp' 'duo' 'solo' 'crashfpp'
#  'flaretpp' 'normal-squad-fpp' 'normal-duo-fpp' 'flarefpp' 'normal-squad'
#  'normal-solo-fpp' 'crashtpp']
# 14

# %%
#14. Plot a barplot of ‘matchType’ vs 'killPoints'. Write your inferences.
sns.barplot(df['matchType'], df['killPoints'])
#inferences : the higher match type is, the higher killPoints too
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#15. Plot a barplot of ‘matchType’ vs ‘weaponsAcquired’. Write your inferences.
plt.bar(df['matchType'], df['weaponsAcquired'])
# i really hard to watch the attributes, even i have changed from seaborn to matplotlib, i am sorry but i can see that there are some weapon type with high acquired with the matchtype
# Out:
# <BarContainer object of 10000 artists>

# %%
#16. Find the Categorical columns.
cols = df.columns
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals',
#        'killPlace', 'killPoints', 'kills', 'killStreaks', 'longestKill',
#        'matchDuration', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %%
print("the categorical are = ", list(set(cols)- set(num_cols)))
# Out:
# the categorical are =  ['matchType', 'matchId', 'Id', 'groupId']

# %%
#18. Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences.
sns.boxplot(df['matchType'], df['winPlacePerc'])
#inference : the average of the matchtype is above 0.5 of 1
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#18. Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences.
sns.boxplot(df['matchType'], df['matchDuration'])
#15.000 to 2000 is average duration
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#19. Change the orientation of the above plot to horizontal.
sns.boxplot(df['matchDuration'], df['matchType'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#20. Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills,teamKills, roadKills.
df['KILL'] = df['headshotKills'] + df['teamKills'] + df['roadKills']
df.head()
# Out:
#                Id         groupId  ... winPlacePerc  KILL
# 0  2f262dd9795e60  78437bcd91d40e  ...       0.0000     0
# 1  a32847cf5bf34b  85b7ce5a12e10b  ...       0.2222     1
# 2  1b1900a9990396  edf80d6523380a  ...       0.8571     1
# 3  f589dd03b60bf2  804ab5e5585558  ...       0.3462     0
# 4  c23c4cc5b78b35  b3e2cd169ed920  ...       0.0690     0
#
# [5 rows x 30 columns]

# %%
#21. Round off column ‘winPlacePerc’ to 2 decimals.
df['winPlacePerc'] = round(df['winPlacePerc'],2)
df.head()
# Out:
#                Id         groupId  ... winPlacePerc  KILL
# 0  2f262dd9795e60  78437bcd91d40e  ...         0.00     0
# 1  a32847cf5bf34b  85b7ce5a12e10b  ...         0.22     1
# 2  1b1900a9990396  edf80d6523380a  ...         0.86     1
# 3  f589dd03b60bf2  804ab5e5585558  ...         0.35     0
# 4  c23c4cc5b78b35  b3e2cd169ed920  ...         0.07     0
#
# [5 rows x 30 columns]

# %%
#22. Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plot it on a histogram and comment on its distribution.
arr = []
for i in range(100):
    arr.append(df['damageDealt'].sample(50).mean())
means = np.array(arr)
sns.distplot(means);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
